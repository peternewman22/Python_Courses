# %%
# %cd "F:\Google Drive\JupyterNotebooks\PMega\Section 11 - Webmaps"
import os
os.listdir()
# Out:
# F:\Google Drive\JupyterNotebooks\PMega\Section 11 - Webmaps
# ['.~$Untitled1.ipynb.insyncdl',
#  '.~$Volcsmap.html.insyncdl',
#  'Aus Volc.txt',
#  'Aus Volc.xlsx',
#  'aus volcs.xlsx',
#  'code.py',
#  'coordinates.json',
#  'debug.txt',
#  'debug_pop.txt',
#  'desktop.ini',
#  'GeoMap Project Polished.ipynb',
#  'GeoMap Project.ipynb',
#  'GVP_Volcano_List.xls',
#  'GVP_Volcano_List.xlsx',
#  'MyMap.html',
#  'myvolcsmap.html',
#  'out.txt',
#  'popmap.html',
#  'Popmap.ipynb',
#  'subVolcs.html',
#  'Testvolcsmap.html',
#  'Untitled0.ipynb',
#  'Volcanoes_USA.csv',
#  'Volcanoes_USA.txt',
#  'VolcanoMap.html',
#  'Volcsmap.html',
#  'VolcsTestMap.html',
#  'world.json',
#  '~$GVP_Volcano_List.xlsx']

# %%
import pandas as pd

data = pd.read_json("coordinates.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-3705f2da742a> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 data = pd.read_json("coordinates.json")
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\io\json\json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     364         return json_reader
#     365
# --> 366     return json_reader.read()
#     367
#     368
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\io\json\json.py in read(self)
#     465             )
#     466         else:
# --> 467             obj = self._get_object_parser(self.data)
#     468         self.close()
#     469         return obj
#
# ...
