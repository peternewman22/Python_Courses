# %%
import plotly

# %%
plotly.tools.set_credentials(username ="peter.newman.22", api_keys = "••••••••••")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-04fbea762192> in <module>
# ----> 1 plotly.tools.set_credentials(username ="peter.newman.22", api_keys = "••••••••••")
#
# AttributeError: module 'plotly.tools' has no attribute 'set_credentials'

# %%
help(plotly.tools)
# Out:
# Help on module plotly.tools in plotly:
#
# NAME
#     plotly.tools
#
# DESCRIPTION
#     tools
#     =====
#
#     Functions that USERS will possibly want access to.
#
# CLASSES
#     builtins.object
#         FigureFactory
#
#     class FigureFactory(builtins.object)
#      |  # Deprecations
#      |
#      |  Static methods defined here:
#      |
#      |  create_2D_density(*args, **kwargs)
#      |
#      |  create_annotated_heatmap(*args, **kwargs)
#      |
#      |  create_candlestick(*args, **kwargs)
#      |
#      |  create_dendrogram(*args, **kwargs)
#      |
#      |  create_distplot(*args, **kwargs)
#      |
#      |  create_facet_grid(*args, **kwargs)
#      |
#      |  create_gantt(*args, **kwargs)
#      |
#      |  create_ohlc(*args, **kwargs)
#      |
#      |  create_quiver(*args, **kwargs)
#      |
#      |  create_scatterplotmatrix(*args, **kwargs)
#      |
#      |  create_streamline(*args, **kwargs)
#      |
#      |  create_table(*args, **kwargs)
#      |
# ...
