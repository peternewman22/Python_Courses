# %% [markdown]
# # Some stuff you'll always need

# %%
import sys
from PyQt4 import QtGui

# %% [markdown]
# # The Basic Building Blocks
#
# ## setGeometry
# * 0,0 is top left, but it's the FRAME that's 0,0, not the window itself

# %%
app = QtGui.QApplication(sys.argv)

window = QtGui.QWidget()
window.setGeometry(50,50,500,300) #setGeometry(start_x,start_y,x_pixels,y_pixels)
window.show()
